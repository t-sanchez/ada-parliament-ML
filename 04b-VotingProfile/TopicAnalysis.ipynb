# %%
import pandas as pd
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import sklearn.ensemble
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, train_test_split, cross_val_predict, learning_curve
import sklearn.metrics

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# There's a lot of columns in the DF. 
# Therefore, we add this option so that we can see more columns
pd.options.display.max_columns = 100
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = '../datas/nlp_results/'
voting_df = pd.read_csv(path+'voting_with_topics.csv')
print('Entries in the DataFrame',voting_df.shape)

#Dropping the useless column
voting_df = voting_df.drop('Unnamed: 0',1)

#Putting numerical values into the columns that should have numerical values
#print(voting_df.columns.values)

num_cols = ['Decision', ' armée', ' asile / immigration', ' assurances', ' budget', ' dunno', ' entreprise/ finance',
           ' environnement', ' famille / enfants', ' imposition', ' politique internationale', ' retraite  ']
voting_df[num_cols] = voting_df[num_cols].apply(pd.to_numeric)

#Inserting the full name at the second position
voting_df.insert(2,'Name', voting_df['FirstName'] + ' ' + voting_df['LastName'])

voting_df.head(3)
# Out:
# Entries in the DataFrame (1713854, 39)
#                                            BillTitle  BusinessNumber  \
# 0  Arrêté fédéral concernant la contribution de l...        20090055
# 1  Arrêté fédéral concernant la contribution de l...        20090055
# 2  Arrêté fédéral concernant la contribution de l...        20090055
#
#                         Name  BusinessShortNumber  \
# 0  Chiara Simoneschi-Cortesi                9.055
# 1      Pascale Bruderer Wyss                9.055
# 2               Guy Parmelin                9.055
#
#                                        BusinessTitle Canton  CantonID  \
# 0  Réduction des disparités économiques et social...     TI        21
# 1  Réduction des disparités économiques et social...     AG         1
# 2  Réduction des disparités économiques et social...     VD        23
#
#   CantonName  Decision                                DecisionText FirstName  \
# 0     Tessin         7  Die Präsidentin/der Präsident stimmt nicht    Chiara
# 1     Aargau         5                      Hat nicht teilgenommen   Pascale
# 2      Waadt         5                      Hat nicht teilgenommen       Guy
#
#         ID  IdLegislativePeriod  IdSession  IdVote Language  \
# 0  1183799                   48       4811    6392       FR
# 1  1183800                   48       4811    6392       FR
# 2  1183801                   48       4811    6392       FR
#
#              LastName                                          MeaningNo  \
# 0  Simoneschi-Cortesi  Proposition de la minorité Stamm (ne pas entre...
# 1       Bruderer Wyss  Proposition de la minorité Stamm (ne pas entre...
# 2            Parmelin  Proposition de la minorité Stamm (ne pas entre...
#
#                                        MeaningYes ParlGroupCode  \
# 0  Proposition de la majorité (entrer en matière)           CEg
# 1  Proposition de la majorité (entrer en matière)             S
# 2  Proposition de la majorité (entrer en matière)             V
#
#   ParlGroupColour                              ParlGroupName  \
# 0       #FFFFA500             Groupe conservateur-catholique
# 1       #FFFF0000                          Groupe socialiste
# 2       #FF006400  Groupe des Paysans, Artisans et Bourgeois
#
#   ParlGroupNameAbbreviation  PersonNumber  RegistrationNumber  \
# 0                  Groupe K           511                2652
# 1                  Groupe S           823                2652
# 2                  Groupe B          1108                2652
#
#              Subject                 VoteEnd  \
# 0  Entrer en matière  2009-09-07T15:44:26.69
# 1  Entrer en matière  2009-09-07T15:44:26.69
# 2  Entrer en matière  2009-09-07T15:44:26.69
#
#                                                 text     armée  \
# 0  Arrêté fédéral concernant la contribution de l...  0.006995
# 1  Arrêté fédéral concernant la contribution de l...  0.006995
# 2  Arrêté fédéral concernant la contribution de l...  0.006995
#
#     asile / immigration   assurances    budget     dunno  \
# 0              0.930066     0.006993  0.006993  0.006993
# 1              0.930066     0.006993  0.006993  0.006993
# 2              0.930066     0.006993  0.006993  0.006993
#
#     entreprise/ finance   environnement   famille / enfants   imposition  \
# 0              0.006994        0.006993            0.006993     0.006993
# 1              0.006994        0.006993            0.006993     0.006993
# 2              0.006994        0.006993            0.006993     0.006993
#
#     politique internationale   retraite
# 0                   0.006993     0.006993
# 1                   0.006993     0.006993
# 2                   0.006993     0.006993

# %% [markdown]
# # Evolution of topics in the votes

# %% [markdown]
# We take a look at the data in order to observe which topics are most talked about in the votes, and see whether or not it changes over the years.

# %%
voting_df_copy = voting_df
voting_df_copy.head(3)
# Out:
#                                            BillTitle  BusinessNumber  \
# 0  Arrêté fédéral concernant la contribution de l...        20090055
# 1  Arrêté fédéral concernant la contribution de l...        20090055
# 2  Arrêté fédéral concernant la contribution de l...        20090055
#
#                         Name  BusinessShortNumber  \
# 0  Chiara Simoneschi-Cortesi                9.055
# 1      Pascale Bruderer Wyss                9.055
# 2               Guy Parmelin                9.055
#
#                                        BusinessTitle Canton  CantonID  \
# 0  Réduction des disparités économiques et social...     TI        21
# 1  Réduction des disparités économiques et social...     AG         1
# 2  Réduction des disparités économiques et social...     VD        23
#
#   CantonName  Decision                                DecisionText FirstName  \
# 0     Tessin         7  Die Präsidentin/der Präsident stimmt nicht    Chiara
# 1     Aargau         5                      Hat nicht teilgenommen   Pascale
# 2      Waadt         5                      Hat nicht teilgenommen       Guy
#
#         ID  IdLegislativePeriod  IdSession  IdVote Language  \
# 0  1183799                   48       4811    6392       FR
# 1  1183800                   48       4811    6392       FR
# 2  1183801                   48       4811    6392       FR
#
#              LastName                                          MeaningNo  \
# 0  Simoneschi-Cortesi  Proposition de la minorité Stamm (ne pas entre...
# 1       Bruderer Wyss  Proposition de la minorité Stamm (ne pas entre...
# 2            Parmelin  Proposition de la minorité Stamm (ne pas entre...
#
#                                        MeaningYes ParlGroupCode  \
# 0  Proposition de la majorité (entrer en matière)           CEg
# 1  Proposition de la majorité (entrer en matière)             S
# 2  Proposition de la majorité (entrer en matière)             V
#
#   ParlGroupColour                              ParlGroupName  \
# 0       #FFFFA500             Groupe conservateur-catholique
# 1       #FFFF0000                          Groupe socialiste
# 2       #FF006400  Groupe des Paysans, Artisans et Bourgeois
#
#   ParlGroupNameAbbreviation  PersonNumber  RegistrationNumber  \
# 0                  Groupe K           511                2652
# 1                  Groupe S           823                2652
# 2                  Groupe B          1108                2652
#
#              Subject                 VoteEnd  \
# 0  Entrer en matière  2009-09-07T15:44:26.69
# 1  Entrer en matière  2009-09-07T15:44:26.69
# 2  Entrer en matière  2009-09-07T15:44:26.69
#
#                                                 text     armée  \
# 0  Arrêté fédéral concernant la contribution de l...  0.006995
# 1  Arrêté fédéral concernant la contribution de l...  0.006995
# 2  Arrêté fédéral concernant la contribution de l...  0.006995
#
#     asile / immigration   assurances    budget     dunno  \
# 0              0.930066     0.006993  0.006993  0.006993
# 1              0.930066     0.006993  0.006993  0.006993
# 2              0.930066     0.006993  0.006993  0.006993
#
#     entreprise/ finance   environnement   famille / enfants   imposition  \
# 0              0.006994        0.006993            0.006993     0.006993
# 1              0.006994        0.006993            0.006993     0.006993
# 2              0.006994        0.006993            0.006993     0.006993
#
#     politique internationale   retraite
# 0                   0.006993     0.006993
# 1                   0.006993     0.006993
# 2                   0.006993     0.006993

# %%
voting_df_copy['VoteEnd'] = [x[:4] for x in voting_df_copy['VoteEnd']]
voting_df_copy.head(3)
dates = voting_df_copy['VoteEnd'].drop_duplicates()
dates = np.sort(dates)
dates
# Out:
# array(['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'], dtype=object)

# %%
#voting_df_copy.index = voting_df_copy['VoteEnd']
voting_df_copy = voting_df_copy.set_index(['VoteEnd', 'Name'])

voting_df_copy.head(3)
# Out:
#                                                                            BillTitle  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi  Arrêté fédéral concernant la contribution de l...
#         Pascale Bruderer Wyss      Arrêté fédéral concernant la contribution de l...
#         Guy Parmelin               Arrêté fédéral concernant la contribution de l...
#
#                                    BusinessNumber  BusinessShortNumber  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi        20090055                9.055
#         Pascale Bruderer Wyss            20090055                9.055
#         Guy Parmelin                     20090055                9.055
#
#                                                                        BusinessTitle  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi  Réduction des disparités économiques et social...
#         Pascale Bruderer Wyss      Réduction des disparités économiques et social...
#         Guy Parmelin               Réduction des disparités économiques et social...
#
#                                   Canton  CantonID CantonName  Decision  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi     TI        21     Tessin         7
#         Pascale Bruderer Wyss         AG         1     Aargau         5
#         Guy Parmelin                  VD        23      Waadt         5
#
#                                                                  DecisionText  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi  Die Präsidentin/der Präsident stimmt nicht
#         Pascale Bruderer Wyss                          Hat nicht teilgenommen
#         Guy Parmelin                                   Hat nicht teilgenommen
#
#                                   FirstName       ID  IdLegislativePeriod  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi    Chiara  1183799                   48
#         Pascale Bruderer Wyss       Pascale  1183800                   48
#         Guy Parmelin                    Guy  1183801                   48
#
#                                    IdSession  IdVote Language  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi       4811    6392       FR
#         Pascale Bruderer Wyss           4811    6392       FR
#         Guy Parmelin                    4811    6392       FR
#
#                                              LastName  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi  Simoneschi-Cortesi
#         Pascale Bruderer Wyss           Bruderer Wyss
#         Guy Parmelin                         Parmelin
#
#                                                                            MeaningNo  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi  Proposition de la minorité Stamm (ne pas entre...
#         Pascale Bruderer Wyss      Proposition de la minorité Stamm (ne pas entre...
#         Guy Parmelin               Proposition de la minorité Stamm (ne pas entre...
#
#                                                                        MeaningYes  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi  Proposition de la majorité (entrer en matière)
#         Pascale Bruderer Wyss      Proposition de la majorité (entrer en matière)
#         Guy Parmelin               Proposition de la majorité (entrer en matière)
#
#                                   ParlGroupCode ParlGroupColour  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi           CEg       #FFFFA500
#         Pascale Bruderer Wyss                 S       #FFFF0000
#         Guy Parmelin                          V       #FF006400
#
#                                                                ParlGroupName  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi             Groupe conservateur-catholique
#         Pascale Bruderer Wyss                              Groupe socialiste
#         Guy Parmelin               Groupe des Paysans, Artisans et Bourgeois
#
#                                   ParlGroupNameAbbreviation  PersonNumber  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi                  Groupe K           511
#         Pascale Bruderer Wyss                      Groupe S           823
#         Guy Parmelin                               Groupe B          1108
#
#                                    RegistrationNumber            Subject  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi                2652  Entrer en matière
#         Pascale Bruderer Wyss                    2652  Entrer en matière
#         Guy Parmelin                             2652  Entrer en matière
#
#                                                                                 text  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi  Arrêté fédéral concernant la contribution de l...
#         Pascale Bruderer Wyss      Arrêté fédéral concernant la contribution de l...
#         Guy Parmelin               Arrêté fédéral concernant la contribution de l...
#
#                                       armée   asile / immigration  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi  0.006995              0.930066
#         Pascale Bruderer Wyss      0.006995              0.930066
#         Guy Parmelin               0.006995              0.930066
#
#                                     assurances    budget     dunno  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi     0.006993  0.006993  0.006993
#         Pascale Bruderer Wyss         0.006993  0.006993  0.006993
#         Guy Parmelin                  0.006993  0.006993  0.006993
#
#                                     entreprise/ finance   environnement  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi              0.006994        0.006993
#         Pascale Bruderer Wyss                  0.006994        0.006993
#         Guy Parmelin                           0.006994        0.006993
#
#                                     famille / enfants   imposition  \
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi            0.006993     0.006993
#         Pascale Bruderer Wyss                0.006993     0.006993
#         Guy Parmelin                         0.006993     0.006993
#
#                                     politique internationale   retraite
# VoteEnd Name
# 2009    Chiara Simoneschi-Cortesi                   0.006993     0.006993
#         Pascale Bruderer Wyss                       0.006993     0.006993
#         Guy Parmelin                                0.006993     0.006993

# %%
voting_df_copy.columns
# Out:
# Index(['BillTitle', 'BusinessNumber', 'BusinessShortNumber', 'BusinessTitle',
#        'Canton', 'CantonID', 'CantonName', 'Decision', 'DecisionText',
#        'FirstName', 'ID', 'IdLegislativePeriod', 'IdSession', 'IdVote',
#        'Language', 'LastName', 'MeaningNo', 'MeaningYes', 'ParlGroupCode',
#        'ParlGroupColour', 'ParlGroupName', 'ParlGroupNameAbbreviation',
#        'PersonNumber', 'RegistrationNumber', 'Subject', 'text', ' armée',
#        ' asile / immigration', ' assurances', ' budget', ' dunno',
#        ' entreprise/ finance', ' environnement', ' famille / enfants',
#        ' imposition', ' politique internationale', ' retraite  '],
#       dtype='object')

# %%
#voting_df_copy.loc['2009-09'][' armée']
#topicArmee = np.mean(voting_df_copy.loc['2009-09'][' armée'])

#print(topicArmee)
#indices = voting_df_copy.index[:].values
#indices

topics = ['armée', 'asile / immigration', 'assurances', 'budget', 'dunno', 'entreprise/ finance', 'environnement', 'famille / enfants', 'imposition', 'politique internationale', 'retraite  ']
topicEvolution = pd.DataFrame(index = dates, columns = topics)
#topicArmeeEvolution = []

for topic in topics:
    for date in dates:
        topicEvolution.loc[date][topic] = np.mean(voting_df_copy.loc[date][' '+topic])
        #topicArmeeEvolution.append(np.mean(voting_df_copy.loc[date][' '+topic]))
    #topicEvolution[topic].plot
    plt.plot(dates,topicEvolution[topic])

plt.legend(topics)
topicEvolution
# Out:
#           armée asile / immigration assurances     budget      dunno  \
# 2009   0.202161            0.104713  0.0389831  0.0848032   0.116052
# 2010   0.114155            0.115763  0.0717884   0.116499   0.112542
# 2011  0.0838769            0.128447  0.0568394   0.105334    0.11252
# 2012   0.092086            0.114097  0.0952089   0.094797   0.143702
# 2013   0.110226           0.0907088  0.0561217   0.131031   0.137501
# 2014  0.0861784            0.103468  0.0494335   0.132928   0.119256
# 2015   0.058689            0.107653   0.078116   0.159178    0.11377
# 2016   0.118936            0.147102  0.0526312   0.124182  0.0752233
#
#      entreprise/ finance environnement famille / enfants imposition  \
# 2009            0.239517     0.0288576         0.0752248  0.0470282
# 2010            0.116178     0.0335786         0.0689063  0.0802596
# 2011            0.202445     0.0488564         0.0724943  0.0828032
# 2012            0.137266     0.0539692         0.0866064  0.0883799
# 2013            0.134538     0.0425515           0.09588  0.0749093
# 2014            0.115441     0.0374378         0.0567515   0.113667
# 2015            0.148992     0.0315432         0.0808357  0.0608155
# 2016            0.145242     0.0413662         0.0988141   0.085135
#
#      politique internationale retraite
# 2009                0.0281682  0.0344929
# 2010                0.0670029   0.103329
# 2011                 0.032848  0.0735355
# 2012                0.0331734  0.0607135
# 2013                 0.059478  0.0670555
# 2014                0.0873126  0.0981259
# 2015                0.0243802   0.136028
# 2016                0.0490565  0.0623114

# %%
topicEvolution.to_json("topicEvolution.json")

# %% [markdown]
# # Extract vote decision for each subject

# %% [markdown]
# We exctract here for each voted subject the final result of the votation, by comparing the number of *Yes* to the number of *No*.

# %%
voting_df = pd.read_csv(path+'voting_with_topics_sentiment.csv')
voting_df_Decision = voting_df
#voting_df_TopicAcceptation = voting_df_TopicAcceptation.set_index(['IdVote', 'Name'])
voting_df_Decision.head(3)
# Out:
#                                            BillTitle  \
# 0  Arrêté fédéral concernant la contribution de l...
# 1  Arrêté fédéral concernant la contribution de l...
# 2  Arrêté fédéral concernant la contribution de l...
#
#                                        BusinessTitle FirstName  \
# 0  Réduction des disparités économiques et social...    Chiara
# 1  Réduction des disparités économiques et social...   Pascale
# 2  Réduction des disparités économiques et social...       Guy
#
#              LastName  Decision  ParlGroupCode  \
# 0  Simoneschi-Cortesi         7              0
# 1       Bruderer Wyss         5              1
# 2            Parmelin         5              2
#
#                                                 text     armée  \
# 0  Arrêté fédéral concernant la contribution de l...  0.006995
# 1  Arrêté fédéral concernant la contribution de l...  0.006995
# 2  Arrêté fédéral concernant la contribution de l...  0.006995
#
#     asile / immigration   assurances    budget     dunno  \
# 0              0.930066     0.006993  0.006993  0.006993
# 1              0.930066     0.006993  0.006993  0.006993
# 2              0.930066     0.006993  0.006993  0.006993
#
#     entreprise/ finance   environnement   famille / enfants   imposition  \
# 0              0.006994        0.006993            0.006993     0.006993
# 1              0.006994        0.006993            0.006993     0.006993
# 2              0.006994        0.006993            0.006993     0.006993
#
#     politique internationale   retraite    \
# 0                   0.006993     0.006993
# 1                   0.006993     0.006993
# 2                   0.006993     0.006993
#
#                                             text_eng  positive  negative  \
# 0  Federal decree on Switzerland's contribution i...     0.075       0.0
# 1  Federal decree on Switzerland's contribution i...     0.075       0.0
# 2  Federal decree on Switzerland's contribution i...     0.075       0.0
#
#    neutral  compound
# 0    0.925    0.4404
# 1    0.925    0.4404
# 2    0.925    0.4404

# %%
texts = voting_df_Decision['text'].unique()
print(len(texts))
texts[0]
# Out:
# 3470
# "Arrêté fédéral concernant la contribution de la Suisse en faveur de la Bulgarie et de la Roumanie au titre de la réduction des disparités économiques et sociales dans l'Union européenne élargie Réduction des disparités économiques et sociales dans l'UE. Contribution de la Suisse en faveur de la Roumanie et de la Bulgarie"

# %%
voting_df_Decision = voting_df_Decision.set_index(['text', 'LastName'])
voting_df_Decision.head()
# Out:
#                                                                                                                BillTitle  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi  Arrêté fédéral concernant la contribution de l...
#                                                    Bruderer Wyss       Arrêté fédéral concernant la contribution de l...
#                                                    Parmelin            Arrêté fédéral concernant la contribution de l...
#                                                    Germanier           Arrêté fédéral concernant la contribution de l...
#                                                    Engelberger         Arrêté fédéral concernant la contribution de l...
#
#                                                                                                            BusinessTitle  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi  Réduction des disparités économiques et social...
#                                                    Bruderer Wyss       Réduction des disparités économiques et social...
#                                                    Parmelin            Réduction des disparités économiques et social...
#                                                    Germanier           Réduction des disparités économiques et social...
#                                                    Engelberger         Réduction des disparités économiques et social...
#
#                                                                        FirstName  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi     Chiara
#                                                    Bruderer Wyss         Pascale
#                                                    Parmelin                  Guy
#                                                    Germanier           Jean-René
#                                                    Engelberger               Edi
#
#                                                                        Decision  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi         7
#                                                    Bruderer Wyss              5
#                                                    Parmelin                   5
#                                                    Germanier                  5
#                                                    Engelberger                5
#
#                                                                        ParlGroupCode  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi              0
#                                                    Bruderer Wyss                   1
#                                                    Parmelin                        2
#                                                    Germanier                       3
#                                                    Engelberger                     3
#
#                                                                           armée  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi  0.006995
#                                                    Bruderer Wyss       0.006995
#                                                    Parmelin            0.006995
#                                                    Germanier           0.006995
#                                                    Engelberger         0.006995
#
#                                                                         asile / immigration  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi              0.930066
#                                                    Bruderer Wyss                   0.930066
#                                                    Parmelin                        0.930066
#                                                    Germanier                       0.930066
#                                                    Engelberger                     0.930066
#
#                                                                         assurances  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi     0.006993
#                                                    Bruderer Wyss          0.006993
#                                                    Parmelin               0.006993
#                                                    Germanier              0.006993
#                                                    Engelberger            0.006993
#
#                                                                          budget  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi  0.006993
#                                                    Bruderer Wyss       0.006993
#                                                    Parmelin            0.006993
#                                                    Germanier           0.006993
#                                                    Engelberger         0.006993
#
#                                                                           dunno  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi  0.006993
#                                                    Bruderer Wyss       0.006993
#                                                    Parmelin            0.006993
#                                                    Germanier           0.006993
#                                                    Engelberger         0.006993
#
#                                                                         entreprise/ finance  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi              0.006994
#                                                    Bruderer Wyss                   0.006994
#                                                    Parmelin                        0.006994
#                                                    Germanier                       0.006994
#                                                    Engelberger                     0.006994
#
#                                                                         environnement  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi        0.006993
#                                                    Bruderer Wyss             0.006993
#                                                    Parmelin                  0.006993
#                                                    Germanier                 0.006993
#                                                    Engelberger               0.006993
#
#                                                                         famille / enfants  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi            0.006993
#                                                    Bruderer Wyss                 0.006993
#                                                    Parmelin                      0.006993
#                                                    Germanier                     0.006993
#                                                    Engelberger                   0.006993
#
#                                                                         imposition  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi     0.006993
#                                                    Bruderer Wyss          0.006993
#                                                    Parmelin               0.006993
#                                                    Germanier              0.006993
#                                                    Engelberger            0.006993
#
#                                                                         politique internationale  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi                   0.006993
#                                                    Bruderer Wyss                        0.006993
#                                                    Parmelin                             0.006993
#                                                    Germanier                            0.006993
#                                                    Engelberger                          0.006993
#
#                                                                         retraite    \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi     0.006993
#                                                    Bruderer Wyss          0.006993
#                                                    Parmelin               0.006993
#                                                    Germanier              0.006993
#                                                    Engelberger            0.006993
#
#                                                                                                                 text_eng  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi  Federal decree on Switzerland's contribution i...
#                                                    Bruderer Wyss       Federal decree on Switzerland's contribution i...
#                                                    Parmelin            Federal decree on Switzerland's contribution i...
#                                                    Germanier           Federal decree on Switzerland's contribution i...
#                                                    Engelberger         Federal decree on Switzerland's contribution i...
#
#                                                                        positive  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi     0.075
#                                                    Bruderer Wyss          0.075
#                                                    Parmelin               0.075
#                                                    Germanier              0.075
#                                                    Engelberger            0.075
#
#                                                                        negative  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi       0.0
#                                                    Bruderer Wyss            0.0
#                                                    Parmelin                 0.0
#                                                    Germanier                0.0
#                                                    Engelberger              0.0
#
#                                                                        neutral  \
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi    0.925
#                                                    Bruderer Wyss         0.925
#                                                    Parmelin              0.925
#                                                    Germanier             0.925
#                                                    Engelberger           0.925
#
#                                                                        compound
# text                                               LastName
# Arrêté fédéral concernant la contribution de la... Simoneschi-Cortesi    0.4404
#                                                    Bruderer Wyss         0.4404
#                                                    Parmelin              0.4404
#                                                    Germanier             0.4404
#                                                    Engelberger           0.4404

# %%
decisions_dict = {}
decisions_dict[texts[0]] = np.sum(voting_df_Decision.loc[texts[0]].Decision == 1) > np.sum(voting_df_Decision.loc[texts[0]].Decision == 2)
for t in texts:
    decisions_dict[t] = np.sum(voting_df_Decision.loc[t].Decision == 1) > np.sum(voting_df_Decision.loc[t].Decision == 2)

# %%
len(decisions_dict)
# Out:
# 3470

# %%
decisions_df = pd.DataFrame.from_dict(decisions_dict, 'index')
decisions_df.columns = ['Decision']
decisions_df.head()
# Out:
#                                                    Decision
#  Donner aux cantons l'autonomie de procéder à u...     True
#  Grandes installations photovoltaïques hors des...    False
#  Pour une sortie de la Suisse de Frontex              False
#  Places de stage dans les cabinets privés et da...     True
#  Plus de places de formation dans la médecine h...     True

# %% [markdown]
# # Ratio of acceptation for each topic

# %% [markdown]
# We now want to see if there is a significant correlation between a vote being accepted and the topic of the vote.

# %%
path = '../datas/nlp_results/'
voting_df = pd.read_csv(path+'voting_with_topics_unique_sentiment.csv')
voting_df_TopicAcceptation = voting_df
#voting_df_TopicAcceptation = voting_df_TopicAcceptation.set_index(['IdVote', 'Name'])
voting_df_TopicAcceptation.head(3)
# Out:
#       armée   asile / immigration   assurances    budget     dunno  \
# 0  0.006995              0.930066     0.006993  0.006993  0.006993
# 1  0.018182              0.018185     0.018183  0.271557  0.564795
# 2  0.015152              0.389858     0.015152  0.232520  0.256405
#
#     entreprise/ finance   environnement   famille / enfants   imposition  \
# 0              0.006994        0.006993            0.006993     0.006993
# 1              0.018183        0.018182            0.018183     0.018183
# 2              0.015152        0.015152            0.015152     0.015152
#
#     politique internationale   retraite    \
# 0                   0.006993     0.006993
# 1                   0.018183     0.018184
# 2                   0.015154     0.015152
#
#                                                 text  \
# 0  Arrêté fédéral concernant la contribution de l...
# 1   Renforcement du Traité sur la non-proliférati...
# 2   Une zone exempte d'armes nucléaires au coeur ...
#
#                                             text_eng  positive  negative  \
# 0  Federal decree on Switzerland's contribution i...     0.075     0.000
# 1   Strengthening of the Treaty on the non-prolif...     0.227     0.206
# 2   A nuclear weapon free zone in the heart of Eu...     0.264     0.176
#
#    neutral  compound
# 0    0.925    0.4404
# 1    0.567    0.0772
# 2    0.560    0.2732

# %%
voting_df_TopicAcceptation['Accepted'] = decisions_df.loc[voting_df_TopicAcceptation['text']].Decision.values
voting_df_TopicAcceptation.head(3)
# Out:
#       armée   asile / immigration   assurances    budget     dunno  \
# 0  0.006995              0.930066     0.006993  0.006993  0.006993
# 1  0.018182              0.018185     0.018183  0.271557  0.564795
# 2  0.015152              0.389858     0.015152  0.232520  0.256405
#
#     entreprise/ finance   environnement   famille / enfants   imposition  \
# 0              0.006994        0.006993            0.006993     0.006993
# 1              0.018183        0.018182            0.018183     0.018183
# 2              0.015152        0.015152            0.015152     0.015152
#
#     politique internationale   retraite    \
# 0                   0.006993     0.006993
# 1                   0.018183     0.018184
# 2                   0.015154     0.015152
#
#                                                 text  \
# 0  Arrêté fédéral concernant la contribution de l...
# 1   Renforcement du Traité sur la non-proliférati...
# 2   Une zone exempte d'armes nucléaires au coeur ...
#
#                                             text_eng  positive  negative  \
# 0  Federal decree on Switzerland's contribution i...     0.075     0.000
# 1   Strengthening of the Treaty on the non-prolif...     0.227     0.206
# 2   A nuclear weapon free zone in the heart of Eu...     0.264     0.176
#
#    neutral  compound Accepted
# 0    0.925    0.4404     True
# 1    0.567    0.0772    False
# 2    0.560    0.2732    False

# %%
topics = [' armée', ' asile / immigration', ' assurances', ' budget', ' dunno', ' entreprise/ finance', ' environnement', ' famille / enfants', ' imposition', ' politique internationale', ' retraite  ']

voting_df_TopicAcceptation['Topic'] = voting_df_TopicAcceptation[topics].idxmax(axis=1)

voting_df_TopicAcceptation.head(3)
# Out:
#       armée   asile / immigration   assurances    budget     dunno  \
# 0  0.006995              0.930066     0.006993  0.006993  0.006993
# 1  0.018182              0.018185     0.018183  0.271557  0.564795
# 2  0.015152              0.389858     0.015152  0.232520  0.256405
#
#     entreprise/ finance   environnement   famille / enfants   imposition  \
# 0              0.006994        0.006993            0.006993     0.006993
# 1              0.018183        0.018182            0.018183     0.018183
# 2              0.015152        0.015152            0.015152     0.015152
#
#     politique internationale   retraite    \
# 0                   0.006993     0.006993
# 1                   0.018183     0.018184
# 2                   0.015154     0.015152
#
#                                                 text  \
# 0  Arrêté fédéral concernant la contribution de l...
# 1   Renforcement du Traité sur la non-proliférati...
# 2   Une zone exempte d'armes nucléaires au coeur ...
#
#                                             text_eng  positive  negative  \
# 0  Federal decree on Switzerland's contribution i...     0.075     0.000
# 1   Strengthening of the Treaty on the non-prolif...     0.227     0.206
# 2   A nuclear weapon free zone in the heart of Eu...     0.264     0.176
#
#    neutral  compound Accepted                 Topic
# 0    0.925    0.4404     True   asile / immigration
# 1    0.567    0.0772    False                 dunno
# 2    0.560    0.2732    False   asile / immigration

# %%
decisions_df2 =voting_df[['text','Accepted','Topic']]
decisions_df2 = decisions_df2.set_index('text')
decisions_df2.to_csv('topic_accepted.csv')

# %%
meanAcceptation = np.mean(voting_df_TopicAcceptation.loc[:, 'Accepted'])
print('Precentage of acceptation of a votation : ', meanAcceptation)
# Out:
# Precentage of acceptation of a votation :  0.655331412104

# %%
voting_df_TopicAcceptation = voting_df_TopicAcceptation[['Topic', 'Accepted']]
voting_df_MeanAcceptation = voting_df_TopicAcceptation.groupby(by='Topic', axis=0).mean()
voting_df_MeanAcceptation
# Out:
#                            Accepted
# Topic
#  armée                     0.589862
#  asile / immigration       0.749465
#  assurances                0.548117
#  budget                    0.620469
#  dunno                     0.601942
#  entreprise/ finance       0.742991
#  environnement             0.520661
#  famille / enfants         0.657658
#  imposition                0.720833
#  politique internationale  0.657534
#  retraite                  0.696850

# %% [markdown]
# We observe **qualitatively** that votations about *army*, *assurances* and *environnement* are less accepted than the votations about other topics in general. Conversly, votations about *asile / immigration*, *enterprise / finance* and *imposition* are more likely to be accepted. This analysis is performed based on a quick look to the data. The aim of the next part is to determine whether or not these observed variatiations are statistically significant.

# %%
#voting_df_MeanAcceptation['Accepted'].plot.hist(by = 'Topic')
voting_df_MeanAcceptation.hist()
plt.show()

# %%
voting_df_TopicAcceptation = voting_df_TopicAcceptation.set_index('Topic')
voting_df_TopicAcceptation.head(3)
# Out:
#                      Accepted
# Topic
#  asile / immigration     True
#  dunno                  False
#  asile / immigration    False

# %% [markdown]
# The aim of the statistical test that we want to use is to determine whether a sample of votations has a mean acceptation that differs from the global mean acceptation. The samples correspond here to the votations about each topic. Thus we apply one statistical test per topic, whose null hypothesis is that the sample about this topic has the same mean acceptation that the global mean, ie 65.5%. The test that we use is a One-sample T test.

# %%
import scipy.stats as stats

for t in topics:
    votationAboutTopic = voting_df_TopicAcceptation.loc[t]
    print('Topic ' + t,'- Number of votations',len(votationAboutTopic.loc[:, 'Accepted']))
    print(stats.ttest_1samp(a= np.array(votationAboutTopic.loc[:,'Accepted']), popmean=meanAcceptation))
    print()
# Out:
# Topic  armée - Number of votations 434
# Ttest_1sampResult(statistic=-2.7697705019658443, pvalue=0.005850777110375586)
#
# Topic  asile / immigration - Number of votations 467
# Ttest_1sampResult(statistic=4.6894938073401846, pvalue=3.6029713344636828e-06)
#
# Topic  assurances - Number of votations 239
# Ttest_1sampResult(statistic=-3.3234671873908743, pvalue=0.0010292361514610798)
#
# Topic  budget - Number of votations 469
# Ttest_1sampResult(statistic=-1.5541597954907025, pvalue=0.12082226015411453)
#
# Topic  dunno - Number of votations 412
# Ttest_1sampResult(statistic=-2.2111976011878141, pvalue=0.027571917161008392)
#
# Topic  entreprise/ finance - Number of votations 428
# Ttest_1sampResult(statistic=4.1452002473425873, pvalue=4.0961257123752814e-05)
#
# Topic  environnement - Number of votations 121
# Ttest_1sampResult(statistic=-2.9529997116064282, pvalue=0.003787200428245817)
#
# Topic  famille / enfants - Number of votations 333
# Ttest_1sampResult(statistic=0.089329385887242763, pvalue=0.92887400382922802)
#
# Topic  imposition - Number of votations 240
# Ttest_1sampResult(statistic=2.2573753466229491, pvalue=0.024888016626950372)
#
# Topic  politique internationale - Number of votations 73
# Ttest_1sampResult(statistic=0.039389489235533787, pvalue=0.96868887718824381)
#
# Topic  retraite   - Number of votations 254
# Ttest_1sampResult(statistic=1.4368408734720779, pvalue=0.15199868958000282)

# %% [markdown]
# We consider a tolerance threshold for the p-value of 5%. Thus we can reject the null hypothesis for several topics :
# - armée : the acceptation mean is lower than the global mean
# - asile / immigration : the acceptation mean is higher than the global mean
# - assurances : the acceptation mean is lower than the global mean
# - entreprise/ finance : the acceptation mean is higher than the global mean
# - environnement : the acceptation mean is lower than the global mean
# - imposition : the acceptation mean is higher than the global mean
