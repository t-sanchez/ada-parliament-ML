# %%
import pandas as pd
import glob
import os
import numpy as np
from time import time
import logging
import gensim
import bz2
import PyPDF2
from bs4 import BeautifulSoup
# Out:
# /Users/Barry/anaconda/lib/python3.5/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")

# %%
dataset = []

path = 'datas/Transcript/'
allFiles = glob.glob(os.path.join(path, '*.csv'))
dataset = []
for file_ in allFiles:
    data = pd.read_csv(file_,index_col=False)
    for index, row in data.iterrows():
        if data.Text[index] == data.Text[index] : 
            data.Text[index]= BeautifulSoup(data.Text[index],'html.parser').text.replace('\n',' ')
    data.to_csv(file_,index=False)
# Out:
# /Users/Barry/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data.head()
# Out:
#    Unnamed: 0 CantonAbbreviation  CantonId     CantonName  CouncilId  \
# 0           0                NaN       NaN            NaN        NaN
# 1           1                 BL      13.0  Bâle-Campagne        1.0
# 2           2                 NE      24.0      Neuchâtel        1.0
# 3           3                 BE       2.0          Berne        1.0
# 4           4                 ZH       1.0         Zurich       99.0
#
#         CouncilName DisplaySpeaker                      End Function     ID  \
# 0               NaN            NaN                      NaN      NaN  61189
# 1  Conseil national          False  2005-12-15T17:24:54.837      P-M  61190
# 2  Conseil national           True  2005-12-15T17:23:04.587        *  61191
# 3  Conseil national           True  2005-12-15T17:19:53.743        *  61192
# 4   Conseil fédéral           True   2005-12-15T17:17:56.04     BR-M  61193
#
#     ...                ParlGroupName  PersonNumber SortOrder SpeakerFirstName  \
# 0   ...                          NaN           NaN        64              NaN
# 1   ...            Groupe socialiste         477.0        63           Claude
# 2   ...       Groupe radical-libéral        1116.0        62           Didier
# 3   ...    Groupe démocrate-chrétien         330.0        61          Norbert
# 4   ...                          NaN          21.0        60        Christoph
#
#         SpeakerFullName  SpeakerLastName                    Start  \
# 0                   NaN              NaN                      NaN
# 1         Janiak Claude           Janiak  2005-12-15T17:23:04.587
# 2     Burkhalter Didier       Burkhalter  2005-12-15T17:19:53.743
# 3  Hochreutener Norbert     Hochreutener   2005-12-15T17:17:56.04
# 4     Blocher Christoph          Blocher  2005-12-15T17:17:23.073
#
#                                                 Text Type  VoteId
# 0  <pd_text><p><i>Gesamtabstimmung - Vote sur l'e...    2  2814.0
# 1  <pd_text><p><i>Abstimmung - Vote</i></p>\n<p>F...    1     NaN
# 2  <pd_text><p>Aux yeux de la majorité, la versio...    1     NaN
# 3  <pd_text><p>Die Kommissionsmehrheit ist hier d...    1     NaN
# 4  <pd_text><p>Ich muss diese Kröte in Bezug auf ...    1     NaN
#
# [5 rows x 29 columns]
