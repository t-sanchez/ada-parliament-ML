# %% [markdown]
# # 02. Machine Learning on the Votations
# What we aim to perform now is predict the topics that are treated in a *Vote*, given the short string description of the title of the law (*BillTitle*) and the *BusinessTitle*. We apply our model, saved at `../datas/lda/ldamodel` to the data from the *Voting* field, in order to prepare it for the machine learning we'll do later on.
#
# ## 0. Usual Imports

# %%
import pandas as pd
import glob
import os
import numpy as np
from time import time
import logging
import gensim
import bz2
import re
from stop_words import get_stop_words

# %% [markdown]
# ## 1. initialisation of function for topic determination
# First of all, we define a function, *getTopicForQuery* in order to obtain the topics probability dsistribution for the *lda* model we're currently using. It will be of use mostly to retrieve the topic probability distribution for the attributes from the merged  *BillTitle* and *BusinessTitle*.

# %%
def getTopicForQuery (question,stoplist,dictionary,lda):
    """
        Returns the topic probability distribution for a given input question, filtering with the stoplist 
        and finding the matches in the dictionary of words we have from our topic modelling algorithm.
        @param question : The string from which we want to extract the topic
        @param stoplist : The list of common words for the language, that we want to exclude
        @param dictionary : The dictionary of all the words we find for a given lda model (associated to lda)
        @param lda : the model of lda (Latent Dirichlet Allocation) that we want to model the topics from.
        @return the topic probability distribution for the given question
    """
    # 1. Question -> Lower case -> Split -> Exclude common words
    temp = question.lower()
    words = re.findall(r'\w+', temp, flags = re.UNICODE | re.LOCALE)
    important_words = []
    important_words = filter(lambda x: x not in stoplist, words)

    # 2. Find matches in the dictionary of words and get the topics
    ques_vec = []
    ques_vec = dictionary.doc2bow(important_words)
    
    return ldamodel.get_document_topics(ques_vec,minimum_probability=0)

# %% [markdown]
# Now we load the lda model we use along with the stop words, in order to have them available for the time we will use them, avoiding to reload them every time we call *getTopicForQuery*. We also load our *lda* model for once.

# %%
stop_words_de = get_stop_words('de')

with open ("../datas/stop_dictionaries/French_stop_words_changed.txt", "r") as myfile:
    stop_words=myfile.read()  
stop_words = stop_words.split(',')

stop_words = stop_words_de+stop_words
ldamodel = gensim.models.LdaModel.load('../datas/lda/ldamodelFR.model', mmap='r')

# %% [markdown]
# ## 2. Creation of the Voting DataFrame
# We load the Voting DataFrame, take only the relevant fields for us and add the topic probability distribution before exporting it. It will be ready for our Machine Learning algorithm later on.

# %%
dataset_tmp = []
path = '../datas/scrap/Voting'
allFiles = glob.glob(os.path.join(path, 'Session*.csv'))

for file_ in allFiles:
    print(file_)
    data_tmp = pd.read_csv(file_)
    dataset_tmp += [data_tmp] 
data_frame = pd.concat(dataset_tmp)
# Out:
# ../datas/scrap/Voting/Sessionid_4907-4909.csv
# ../datas/scrap/Voting/Sessionid_4818-4820.csv
# ../datas/scrap/Voting/Sessionid_4919-5001.csv
# ../datas/scrap/Voting/Sessionid_5002-5004.csv
# ../datas/scrap/Voting/Sessionid_4913-4915.csv
# ../datas/scrap/Voting/Sessionid_4916-4918.csv
# ../datas/scrap/Voting/Sessionid_4815-4817.csv
# ../datas/scrap/Voting/Sessionid_4904-4906.csv
# ../datas/scrap/Voting/Sessionid_4813-4814.csv
# ../datas/scrap/Voting/Sessionid_4910-4912.csv
# ../datas/scrap/Voting/Sessionid_4811-4812.csv
# ../datas/scrap/Voting/Sessionid_4901-4903.csv
# ../datas/scrap/Voting/Sessionid_5005-5005.csv

# %% [markdown]
# ### 2.1 slection of interesting fields in data_frame
# We take only the relevant fields to us, that is
# - *BillTitle* : The name of the voted law
# - *BusinessTitle* : The description of what is talked about at the parliament
# - *FirstName* and *LastName* : The name of the persone voting
# - *Decision* : The vote of the person
# - *text* : a field which combine *BillTitle* and *BusinessTitle*, we will have a better NLP clustering using this field with our LDA model.

# %%
parl = data_frame.ParlGroupCode.unique().tolist()
#for group in parl :
#    data_frame.loc[data_frame.ParlGroupCode==group,'ParlGroupCode']= parl.index(group)

# %%
data_frame.head()
# Out:
#    Unnamed: 0                                          BillTitle  \
# 0           0  Loi fédérale concernant la redevance pour l’ut...
# 1           1  Loi fédérale concernant la redevance pour l’ut...
# 2           2  Loi fédérale concernant la redevance pour l’ut...
# 3           3  Loi fédérale concernant la redevance pour l’ut...
# 4           4  Loi fédérale concernant la redevance pour l’ut...
#
#    BusinessNumber  BusinessShortNumber  \
# 0        20120018               12.018
# 1        20120018               12.018
# 2        20120018               12.018
# 3        20120018               12.018
# 4        20120018               12.018
#
#                                        BusinessTitle Canton  CantonID  \
# 0  Arrêté fédéral sur le réseau des routes nation...     VD        23
# 1  Arrêté fédéral sur le réseau des routes nation...     VD        23
# 2  Arrêté fédéral sur le réseau des routes nation...     ZH        26
# 3  Arrêté fédéral sur le réseau des routes nation...     ZH        26
# 4  Arrêté fédéral sur le réseau des routes nation...     ZH        26
#
#   CantonName  Decision DecisionText           ...            \
# 0      Waadt         2         Nein           ...
# 1      Waadt         2         Nein           ...
# 2     Zürich         2         Nein           ...
# 3     Zürich         1           Ja           ...
# 4     Zürich         3   Enthaltung           ...
#
#                                MeaningNo                      MeaningYes  \
# 0  Antrag der Minderheit II Grossen Jürg  Antrag der Minderheit I Pieren
# 1  Antrag der Minderheit II Grossen Jürg  Antrag der Minderheit I Pieren
# 2  Antrag der Minderheit II Grossen Jürg  Antrag der Minderheit I Pieren
# 3  Antrag der Minderheit II Grossen Jürg  Antrag der Minderheit I Pieren
# 4  Antrag der Minderheit II Grossen Jürg  Antrag der Minderheit I Pieren
#
#    ParlGroupCode  ParlGroupColour                              ParlGroupName  \
# 0              G        #FF90EE90                          Groupe écologiste
# 1              S        #FFFF0000                          Groupe socialiste
# 2             GL        #FFEE82EE                        Groupe vert'libéral
# 3              V        #FF006400  Groupe des Paysans, Artisans et Bourgeois
# 4             CE        #FFFFA500             Groupe conservateur-catholique
#
#   ParlGroupNameAbbreviation PersonNumber RegistrationNumber  \
# 0                  Groupe G         3907               8448
# 1                  Groupe S         3923               8448
# 2                 Groupe GL         3897               8448
# 3                  Groupe B         3902               8448
# 4                  Groupe K         3904               8448
#
#                   Subject                 VoteEnd
# 0  Art. 6, Abs. 1, Bst. a  2013-03-04T15:15:39.98
# 1  Art. 6, Abs. 1, Bst. a  2013-03-04T15:15:39.98
# 2  Art. 6, Abs. 1, Bst. a  2013-03-04T15:15:39.98
# 3  Art. 6, Abs. 1, Bst. a  2013-03-04T15:15:39.98
# 4  Art. 6, Abs. 1, Bst. a  2013-03-04T15:15:39.98
#
# [5 rows x 27 columns]

# %%
votation_frame = data_frame#[['BillTitle','BusinessTitle','FirstName','LastName','Decision','ParlGroupCode','VoteEnd']]
votation_frame = votation_frame.fillna(value='')
votation_frame['text'] = votation_frame['BillTitle']+' '+votation_frame['BusinessTitle']

# %% [markdown]
# We create a smaller DataFrame which contains only the subjects that are voted, we do not repeat the text each time for each person who votes. Hence we will perform the NLP once on each unique entry.

# %%
text_dict = {'text': votation_frame.text.unique()}
topic_learning_frame = pd.DataFrame(text_dict)
topic_learning_frame.head()
# Out:
#                                                 text
# 0  Loi fédérale concernant la redevance pour l’ut...
# 1  Loi fédérale sur la protection de l'environnem...
# 2  Loi fédérale sur la protection des eaux (LEaux...
# 3  Arrêté fédéral portant approbation et mise en ...
# 4            Aide à la presse. Protéger la diversité

# %% [markdown]
# ## 3 Topic Clustering
#
# We define first the function *insert_topic*, which creates a dictionary containing the topics for all texts in a *data_frame*.

# %%
def insert_topic(data_frame) :
    dict_ = {}
    dict_['text'] =data_frame['text'].values
    with open ("../datas/lda/topics.txt", "r") as myfile:
        s=myfile.read()  
    topics = s.split('\n')
    topics_dic = {}
    for topic in topics :
        if len(topic)>1 :
            name = topic.split(':')
        topics_dic[name[0]] = name[1]
    dictionary = gensim.corpora.Dictionary.load('../datas/lda/ldaDictionaryFR.dict')
    for index, text in zip(data_frame.index,data_frame['text'].values) :
        if index%1000 == 0 :
             print(index)
        for topic in getTopicForQuery(text,stop_words,dictionary,ldamodel) :
            if (topics_dic[str(topic[0])]) in dict_ :
                dict_[topics_dic[str(topic[0])]] +=[topic[1]]
            else :
                dict_[topics_dic[str(topic[0])]] =[topic[1]]
    return dict_

# %%
if not os.path.exists("../datas/nlp_results"):
    os.makedirs("../datas/nlp_results")

# %% [markdown]
# We now create a frame using the topics found using *insert_topic*

# %%
from yandex_translate import YandexTranslate
translate = YandexTranslate('trnsl.1.1.20161208T132730Z.fe490b34d7db4e4f.0a4c7781a0273d520073a1550b6a6624c1c3fd0a')
text_eng = []
for text in topic_learning_frame.text:
    s = translate.translate(text, 'fr-en')
    text_eng += [s['text'][0]]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-161-6e6751b62cfc> in <module>()
# ----> 1 from yandex_translate import YandexTranslate
#       2 translate = YandexTranslate('trnsl.1.1.20161208T132730Z.fe490b34d7db4e4f.0a4c7781a0273d520073a1550b6a6624c1c3fd0a')
#       3 text_eng = []
#       4 for text in topic_learning_frame.text:
#       5     s = translate.translate(text, 'fr-en')
#
# ImportError: No module named 'yandex_translate'

# %%
topics_dict = insert_topic(topic_learning_frame)
topics_frame = pd.DataFrame(topics_dict)
#topics_frame['text_eng'] =  text_eng
# Out:
# 0
# 1000
# 2000
# 3000

# %%
topics_frame.head(200)
#topics_frame.to_csv('../datas/nlp_results/voting_with_topics_unique.csv',index=False)
# Out:
#         Armée  Budget / Dépenses     Dunno  Economie / Travail  \
# 0    0.010102           0.596353  0.010101            0.010101
# 1    0.011364           0.011364  0.011364            0.011364
# 2    0.022728           0.022728  0.022728            0.022727
# 3    0.010101           0.010101  0.010101            0.010101
# 4    0.545446           0.045456  0.045457            0.045455
# 5    0.022728           0.022728  0.022728            0.022728
# 6    0.030307           0.030316  0.030303            0.030304
# 7    0.045458           0.045455  0.045455            0.545443
# 8    0.022728           0.022728  0.022728            0.022728
# 9    0.022727           0.022729  0.022727            0.022727
# 10   0.022728           0.022727  0.022728            0.022727
# 11   0.012987           0.012988  0.012987            0.012987
# 12   0.347100           0.018183  0.018183            0.018183
# 13   0.030304           0.030305  0.696949            0.030305
# 14   0.011364           0.011364  0.011364            0.740090
# 15   0.008265           0.008265  0.008264            0.008265
# 16   0.007576           0.007576  0.007576            0.158624
# 17   0.018182           0.018182  0.018182            0.423087
# 18   0.009091           0.009091  0.009091            0.105607
# 19   0.009091           0.009091  0.009091            0.139501
# 20   0.008265           0.008265  0.008265            0.160530
# 21   0.011364           0.011364  0.011364            0.151039
# 22   0.011364           0.011364  0.011364            0.151116
# 23   0.045456           0.045460  0.045459            0.045457
# 24   0.012987           0.012988  0.012987            0.012996
# 25   0.772713           0.022728  0.022728            0.022728
# 26   0.012987           0.012987  0.012987            0.012990
# 27   0.018187           0.018185  0.018186            0.018184
# 28   0.030304           0.030304  0.030305            0.030304
# 29   0.030305           0.030308  0.030307            0.696940
# ..        ...                ...       ...                 ...
# 170  0.012987           0.012987  0.313672            0.012987
# 171  0.006993           0.006993  0.516051            0.006993
# 172  0.018183           0.018184  0.018183            0.544629
# 173  0.018182           0.018182  0.018182            0.018182
# 174  0.015152           0.015152  0.015152            0.015152
# 175  0.022728           0.022727  0.022731            0.022736
# 176  0.015153           0.015152  0.015153            0.015152
# 177  0.015153           0.015152  0.848478            0.015152
# 178  0.010104           0.010101  0.688993            0.010101
# 179  0.772715           0.022728  0.022729            0.022728
# 180  0.015153           0.015152  0.015152            0.015152
# 181  0.012988           0.012990  0.012987            0.012987
# 182  0.018184           0.018182  0.018182            0.018182
# 183  0.030305           0.030304  0.030303            0.030303
# 184  0.010101           0.010101  0.010101            0.010101
# 185  0.012988           0.176913  0.012988            0.012988
# 186  0.030304           0.030304  0.030310            0.030306
# 187  0.045457           0.045462  0.045458            0.045459
# 188  0.018184           0.018183  0.018183            0.018182
# 189  0.018185           0.018184  0.471068            0.018184
# 190  0.382929           0.015152  0.015152            0.015152
# 191  0.012987           0.012987  0.012987            0.012987
# 192  0.045458           0.045455  0.045455            0.045455
# 193  0.030303           0.030303  0.030304            0.030303
# 194  0.007576           0.007577  0.101684            0.256429
# 195  0.018183           0.818173  0.018183            0.018183
# 196  0.007576           0.007576  0.007576            0.924236
# 197  0.022728           0.022728  0.022728            0.772722
# 198  0.022728           0.022730  0.022730            0.022729
# 199  0.012987           0.012987  0.012988            0.012987
#
#      Environnement / Transports  Fiscalité  Juridiction  \
# 0                      0.010101   0.312733     0.010101
# 1                      0.011364   0.886359     0.011364
# 2                      0.022729   0.022730     0.022728
# 3                      0.898988   0.010101     0.010101
# 4                      0.045455   0.045455     0.045457
# 5                      0.022728   0.772716     0.022730
# 6                      0.030303   0.696941     0.030305
# 7                      0.045455   0.045456     0.045457
# 8                      0.022728   0.772720     0.022727
# 9                      0.022727   0.772725     0.022727
# 10                     0.022727   0.772722     0.022729
# 11                     0.012988   0.709119     0.012988
# 12                     0.018183   0.489252     0.018183
# 13                     0.030304   0.030304     0.030304
# 14                     0.011364   0.011364     0.011364
# 15                     0.008264   0.008265     0.008265
# 16                     0.773193   0.007576     0.007576
# 17                     0.413273   0.018182     0.018182
# 18                     0.812573   0.009091     0.009091
# 19                     0.778678   0.009091     0.009091
# 20                     0.765083   0.008265     0.008265
# 21                     0.746686   0.011364     0.011364
# 22                     0.746609   0.011364     0.011364
# 23                     0.545433   0.045456     0.045457
# 24                     0.012988   0.012988     0.870111
# 25                     0.022728   0.022729     0.022729
# 26                     0.681255   0.012987     0.012988
# 27                     0.018184   0.018185     0.018186
# 28                     0.030304   0.030303     0.030303
# 29                     0.030311   0.030304     0.030306
# ..                          ...        ...          ...
# 170                    0.449057   0.133370     0.012987
# 171                    0.006993   0.006993     0.006994
# 172                    0.018183   0.018183     0.018185
# 173                    0.018182   0.818178     0.018182
# 174                    0.015153   0.584825     0.015152
# 175                    0.772703   0.022728     0.022729
# 176                    0.015152   0.206167     0.299794
# 177                    0.015152   0.015152     0.015152
# 178                    0.010102   0.010102     0.010102
# 179                    0.022728   0.022728     0.022728
# 180                    0.015152   0.848480     0.015152
# 181                    0.012987   0.870122     0.012988
# 182                    0.255286   0.581065     0.018184
# 183                    0.030303   0.696961     0.030304
# 184                    0.010101   0.389087     0.010101
# 185                    0.012987   0.012988     0.012988
# 186                    0.030305   0.030307     0.030307
# 187                    0.045461   0.045461     0.045457
# 188                    0.018183   0.018184     0.307338
# 189                    0.018182   0.018183     0.018184
# 190                    0.015152   0.480701     0.015152
# 191                    0.012987   0.701361     0.012988
# 192                    0.045455   0.545451     0.045455
# 193                    0.030303   0.030303     0.030303
# 194                    0.581274   0.007576     0.007576
# 195                    0.018183   0.018182     0.018182
# 196                    0.007577   0.007577     0.007576
# 197                    0.022728   0.022728     0.022727
# 198                    0.022729   0.022732     0.022729
# 199                    0.239032   0.477470     0.012988
#
#      Politique internationale  Recherche / Education  Santé / Assurances  \
# 0                    0.010102               0.010101            0.010102
# 1                    0.011365               0.011364            0.011364
# 2                    0.022730               0.022727            0.022728
# 3                    0.010101               0.010101            0.010101
# 4                    0.045455               0.045455            0.045455
# 5                    0.022729               0.022728            0.022728
# 6                    0.030306               0.030306            0.030306
# 7                    0.045455               0.045456            0.045455
# 8                    0.022728               0.022727            0.022731
# 9                    0.022727               0.022727            0.022728
# 10                   0.022729               0.022727            0.022727
# 11                   0.173993               0.012988            0.012988
# 12                   0.018183               0.018182            0.018184
# 13                   0.030303               0.030305            0.030309
# 14                   0.011364               0.011364            0.011367
# 15                   0.406672               0.518946            0.008265
# 16                   0.007576               0.007576            0.007576
# 17                   0.018184               0.018182            0.018182
# 18                   0.009093               0.009091            0.009091
# 19                   0.009092               0.009091            0.009091
# 20                   0.008266               0.008265            0.008266
# 21                   0.011365               0.011364            0.011364
# 22                   0.011365               0.011364            0.011364
# 23                   0.045457               0.045456            0.045455
# 24                   0.012988               0.012989            0.012989
# 25                   0.022728               0.022729            0.022730
# 26                   0.012990               0.012987            0.201852
# 27                   0.018185               0.018185            0.018186
# 28                   0.386517               0.030304            0.340743
# 29                   0.030305               0.030305            0.030305
# ..                        ...                    ...                 ...
# 170                  0.012987               0.012987            0.012987
# 171                  0.094479               0.006994            0.006993
# 172                  0.018183               0.018184            0.291719
# 173                  0.018182               0.018182            0.018182
# 174                  0.015152               0.015152            0.278806
# 175                  0.022734               0.022727            0.022727
# 176                  0.372818               0.015152            0.015152
# 177                  0.015152               0.015152            0.015152
# 178                  0.010102               0.010102            0.010102
# 179                  0.022727               0.022730            0.022728
# 180                  0.015152               0.015152            0.015152
# 181                  0.012987               0.012988            0.012988
# 182                  0.018182               0.018183            0.018185
# 183                  0.030303               0.030304            0.030304
# 184                  0.520001               0.010101            0.010102
# 185                  0.012987               0.012989            0.012988
# 186                  0.030304               0.696942            0.030305
# 187                  0.045458               0.545414            0.045458
# 188                  0.018183               0.018183            0.529014
# 189                  0.018185               0.018184            0.018184
# 190                  0.015152               0.015153            0.015152
# 191                  0.012988               0.012988            0.181751
# 192                  0.045455               0.045455            0.045455
# 193                  0.030303               0.030303            0.696964
# 194                  0.007578               0.007577            0.007577
# 195                  0.018183               0.018183            0.018182
# 196                  0.007576               0.007577            0.007576
# 197                  0.022727               0.022728            0.022728
# 198                  0.022728               0.772707            0.022729
# 199                  0.012987               0.179596            0.012989
#
#      Sécurité intérieure                                               text
# 0               0.010101  Loi fédérale concernant la redevance pour l’ut...
# 1               0.011364  Loi fédérale sur la protection de l'environnem...
# 2               0.772716  Loi fédérale sur la protection des eaux (LEaux...
# 3               0.010102  Arrêté fédéral portant approbation et mise en ...
# 4               0.045455            Aide à la presse. Protéger la diversité
# 5               0.022728           Assurer un trafic d'agglomération fluide
# 6               0.030303   Augmenter la sécurité sur les passages pour p...
# 7               0.045457   Pas de libéralisation complète du marché des ...
# 8               0.022727   Prévention des risques sismiques. Règles pour...
# 9               0.022727          Assainissement phonique du réseau routier
# 10              0.022727   Pour une réévaluation immédiate des dangers s...
# 11              0.012988   Bâtiments non utilisés dans les zones agricol...
# 12              0.018185   Appels d'urgence. Mettre à jour les prescript...
# 13              0.030308       Transparence du rapport de gestion de la SSR
# 14              0.157632  Loi fédérale sur les banques et les caisses d'...
# 15              0.008265  Loi fédérale sur l’imposition des frais de for...
# 16              0.007576  Arrêté fédéral portant approbation d'un protoc...
# 17              0.018182     Double imposition. Convention avec le Portugal
# 18              0.009091  Arrêté fédéral portant approbation d'une conve...
# 19              0.009092  Arrêté fédéral portant approbation d'un protoc...
# 20              0.008265  Arrêté fédéral portant approbation d'un protoc...
# 21              0.011364  Arrêté fédéral portant approbation d'une conve...
# 22              0.011364  Arrêté fédéral portant approbation d'une conve...
# 23              0.045455   Conséquences des CDI et des AERF sur la polit...
# 24              0.012988   Force du franc. Harmonisation partielle des h...
# 25              0.022729   Les gardes-frontière doivent garantir la sécu...
# 26              0.012988   Importations de viande assaisonnée. Abolition...
# 27              0.818147   Application correcte de loi sur la surveillan...
# 28              0.030307                  Transparence du marché immobilier
# 29              0.030304                      Politique de change de la BNS
# ..                   ...                                                ...
# 170             0.012990   Lutte contre le trafic de cocaïne. Conclusion...
# 171             0.333523  Loi fédérale sur l’interdiction d’exercer une ...
# 172             0.018183   Davantage de transparence dans le secteur des...
# 173             0.018183   Cadastre des bâtiments contenant de l'amiante...
# 174             0.015152   Renforcer la surveillance financière et évite...
# 175             0.022729   La loi fédérale sur la circulation routière v...
# 176             0.015154   Instauration exceptionnelle de péages routier...
# 177             0.015153  Règlement du Conseil national (RCN) (Améliorat...
# 178             0.220089   Elaboration d'une stratégie plus active visan...
# 179             0.022733   Motions et postulats des conseils législatifs...
# 180             0.015152  Loi fédérale sur la réduction du bruit émis pa...
# 181             0.012987  Arrêté fédéral sur le financement de la réduct...
# 182             0.018184   Désaffectation des centrales nucléaires suiss...
# 183             0.030306   Dépôt définitif pour les déchets radioactifs....
# 184             0.010101   Taxe sur le CO2 et obligation de compenser le...
# 185             0.706195   Modification des conditions donnant droit aux...
# 186             0.030303                     Géothermie profonde. Offensive
# 187             0.045456                Avenir de l'énergie. Plus de marché
# 188             0.018184   Marché de l'énergie. Les fournisseurs et les ...
# 189             0.365276   Plan directeur national pour la géothermie et...
# 190             0.015152   Concept Romandie des CFF. Garder l'attractivi...
# 191             0.012987   Rétribution à prix coûtant du courant injecté...
# 192             0.045455     Sécuriser la semi-autoroute A9 Orbe-Ballaigues
# 193             0.030308                           Prescription de Ritaline
# 194             0.007577  Arrêté fédéral concernant le renouvellement de...
# 195             0.018184  Loi fédérale sur le programme de consolidation...
# 196             0.007577  Loi fédérale sur des mesures visant à facilite...
# 197             0.022728   Dirigeants des banques. Garantie d'une activi...
# 198             0.022729             Mesures visant à protéger les abeilles
# 199             0.012989   Extension de la suspension concernant l'utili...
#
# [200 rows x 12 columns]

# %% [markdown]
# Finally merging the topics with the original frame containing the name and decision of parlementeer ?

# %%
(pd.merge(votation_frame,topics_frame)).to_csv('../datas/nlp_results/voting_with_topics.csv',index=False)

# %%
def insert_topic_unique(data_frame) :
    dict_ = {}
    dict_['text'] =data_frame['text'].values
    dict_['Topic'] = []
    with open ("../datas/lda/topics.txt", "r") as myfile:
        s=myfile.read()  
    topics = s.split('\n')
    topics_dic = {}
    for topic in topics :
        if len(topic)>1 :
            name = topic.split(':')
        topics_dic[name[0]] = name[1]
    dictionary = gensim.corpora.Dictionary.load('../datas/lda/ldaDictionary')
    for index, text in zip(data_frame.index,data_frame['text'].values) :
        if index%1000 == 0 :
            print(index)
        max_ = 0
        for topic in getTopicForQuery(text,stop_words,dictionary,ldamodel) :
            max_old = max_
            max_ = max(max_,topic[1])
            if max_old != max_ :
                topic_id = topic[0]
    
        dict_['Topic'] += [topics_dic[str(topic_id)]]
    return dict_

# %%
topics_s = insert_topic_unique(topic_learning_frame)
topics_ss = pd.DataFrame(topics_s)
topics_ss.head()
# Out:
# 0
# /Users/Barry/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:13: DeprecationWarning: LOCALE flag with a str pattern is deprecated. Will be an error in 3.6
# 1000
# 2000
# 3000
#                   Topic                                               text
# 0   asile / immigration  Arrêté fédéral concernant la contribution de l...
# 1                 dunno   Renforcement du Traité sur la non-proliférati...
# 2   asile / immigration   Une zone exempte d'armes nucléaires au coeur ...
# 3   asile / immigration   Boycott de la liste des terroristes établie p...
# 4   asile / immigration   Ratification du Protocole de l'ONU sur les ar...

# %%
topics_ss.to_csv("../datas/nlp_results/voting_single_topic.csv")

# %%
data_complete = (pd.merge(votation_frame,topics_ss))
data_complete.head(2)
# Out:
#    Unnamed: 0                                          BillTitle  \
# 0           0  Arrêté fédéral concernant la contribution de l...
# 1           1  Arrêté fédéral concernant la contribution de l...
#
#    BusinessNumber  BusinessShortNumber  \
# 0        20090055                9.055
# 1        20090055                9.055
#
#                                        BusinessTitle Canton  CantonID  \
# 0  Réduction des disparités économiques et social...     TI        21
# 1  Réduction des disparités économiques et social...     AG         1
#
#   CantonName  Decision                                DecisionText  \
# 0     Tessin         7  Die Präsidentin/der Präsident stimmt nicht
# 1     Aargau         5                      Hat nicht teilgenommen
#
#            ...          ParlGroupCode  ParlGroupColour  \
# 0          ...                    CEg        #FFFFA500
# 1          ...                      S        #FFFF0000
#
#                     ParlGroupName  ParlGroupNameAbbreviation  PersonNumber  \
# 0  Groupe conservateur-catholique                   Groupe K           511
# 1               Groupe socialiste                   Groupe S           823
#
#   RegistrationNumber            Subject                 VoteEnd  \
# 0               2652  Entrer en matière  2009-09-07T15:44:26.69
# 1               2652  Entrer en matière  2009-09-07T15:44:26.69
#
#                                                 text                 Topic
# 0  Arrêté fédéral concernant la contribution de l...   asile / immigration
# 1  Arrêté fédéral concernant la contribution de l...   asile / immigration
#
# [2 rows x 29 columns]

# %%
data_complete.VoteEnd = [x[:10] for x in data_complete.VoteEnd]
data_complete.head(2)
# Out:
#    Unnamed: 0                                          BillTitle  \
# 0           0  Arrêté fédéral concernant la contribution de l...
# 1           1  Arrêté fédéral concernant la contribution de l...
#
#    BusinessNumber  BusinessShortNumber  \
# 0        20090055                9.055
# 1        20090055                9.055
#
#                                        BusinessTitle Canton  CantonID  \
# 0  Réduction des disparités économiques et social...     TI        21
# 1  Réduction des disparités économiques et social...     AG         1
#
#   CantonName  Decision                                DecisionText  \
# 0     Tessin         7  Die Präsidentin/der Präsident stimmt nicht
# 1     Aargau         5                      Hat nicht teilgenommen
#
#            ...          ParlGroupCode  ParlGroupColour  \
# 0          ...                    CEg        #FFFFA500
# 1          ...                      S        #FFFF0000
#
#                     ParlGroupName  ParlGroupNameAbbreviation  PersonNumber  \
# 0  Groupe conservateur-catholique                   Groupe K           511
# 1               Groupe socialiste                   Groupe S           823
#
#   RegistrationNumber            Subject     VoteEnd  \
# 0               2652  Entrer en matière  2009-09-07
# 1               2652  Entrer en matière  2009-09-07
#
#                                                 text                 Topic
# 0  Arrêté fédéral concernant la contribution de l...   asile / immigration
# 1  Arrêté fédéral concernant la contribution de l...   asile / immigration
#
# [2 rows x 29 columns]

# %%
not_used = ['Unnamed: 0','BusinessNumber','BusinessShortNumber','CantonID','ID','IdLegislativePeriod',
           'IdSession','IdVote','PersonNumber','RegistrationNumber','BillTitle','BusinessTitle','DecisionText',
           'Language','MeaningNo','MeaningYes','ParlGroupColour','ParlGroupCode','ParlGroupNameAbbreviation',
           'Subject','text']
data_used = data_complete.drop(not_used ,axis=1)
#data_used.head()
data_mean = data_used.set_index(['VoteEnd','Topic','FirstName'])

# %%
data_mean.head(1000)
data_used.to_csv("../datas/nlp_results/voting_single_topic_not_unique.csv")

# %%
for year in data_mean.index.get_level_values('VoteEnd').unique() :
    for Topic in data_mean.loc[year].index.get_level_values('Topic').unique() :
        print("the {0} the subject : {1} had a result of {2}".format(
                year,Topic,data_mean.loc[year,Topic].Decision.mean()))
